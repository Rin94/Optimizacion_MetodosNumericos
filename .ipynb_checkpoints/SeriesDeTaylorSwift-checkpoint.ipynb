# %% [markdown]
# ![title](img/taylor.jpg)

# %% [markdown]
# #### Importar Librerias

# %%
import math
import numpy as np
import sympy as sy
import matplotlib.pyplot as plt
from sympy.functions import sin,cos

# %% [markdown]
# #### Funciones matematicas

# %%
def factorial(n):
    if n<=0:
        return 1
    else:
        return n*factorial(n-1)
        
def taylor(func,x0,n):
    i = 0
    p = 0
    while i <= n:
        p = p + (func.diff(x,i).subs(x,x0))/(factorial(i))*(x-x0)**i
        i += 1
    return p

# %% [markdown]
# #### Gráficamos resultados

# %%
def plot(f,orden):
    x_lims = [-2*np.pi, 2*np.pi]
    #x_lims = [0, 1]
    x1 = np.linspace(x_lims[0],x_lims[1],100)
    y1 = []
    for j in range(1,orden,2):
        print(j)
        func = taylor(f,0,j)
        print('Taylor en n='+str(j),func)
        for k in x1:
            y1.append(func.subs(x,k))
        plt.plot(x1,y1,label='order '+str(j))
        y1 = []
    plt.plot(x1,np.sin(x1),label='sin of x')
    plt.xlim(x_lims)
    plt.ylim([-5,5])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.title('Taylor Swift approximation series')
    plt.show()

# %%
plt.style.use("ggplot")
x = sy.Symbol('x')
f = sin(x)
orden=11
plot(f,orden)
# Out:
# 1
# x
# Taylor en n=1 x
# 3
# x
# Taylor en n=3 -x**3/6 + x
# 5
# x
# Taylor en n=5 x**5/120 - x**3/6 + x
# 7
# x
# Taylor en n=7 -x**7/5040 + x**5/120 - x**3/6 + x
# 9
# x
# Taylor en n=9 x**9/362880 - x**7/5040 + x**5/120 - x**3/6 + x

# %%
from sympy import *
x = Symbol("x")
f = Function("f")(x)
diff(3*x + 2, x) # == 3
diff(f, x).subs(f, 3*x + 2)
# Out:
# Derivative(3*x + 2, x)

# %%
diff(f, x).subs(f, 3*x + 2).doit()
# Out:
# 3
